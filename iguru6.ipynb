# %% [markdown]
# <a href="https://colab.research.google.com/github/ScriptSherpa/python-and-ds/blob/main/iguru6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Datefrane --> represent the data in tabular format

emp_info ={'id':[101,103,102],'name':['john','alex','smith'],
           'dept':['IT','sales','finnance'], 'salary':[34000,56000,778000]}
print(emp_info)
# Out:
# {'id': [101, 103, 102], 'name': ['john', 'alex', 'smith'], 'dept': ['IT', 'sales', 'finnance'], 'salary': [34000, 56000, 778000]}

# %%
data = pd.DataFrame(emp_info)
print(data)
print(type(data))
# Out:
#     id   name      dept  salary
# 0  101   john        IT   34000
# 1  103   alex     sales   56000
# 2  102  smith  finnance  778000
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#     id   name      dept  salary
# 0  101   john        IT   34000
# 1  103   alex     sales   56000
# 2  102  smith  finnance  778000

# %%
emp_info ={'name':['john','alex','smith'],
           'dept':['IT','sales','finnance'], 'salary':[34000,56000,778000]}
data = pd.DataFrame(emp_info,index=[101,102,103])
data
# Out:
#       name      dept  salary
# 101   john        IT   34000
# 102   alex     sales   56000
# 103  smith  finnance  778000

# %%
print(data.shape)
# Out:
# (3, 3)

# %%
print(data['dept'].values)
data.columns
# Out:
# ['IT' 'sales' 'finnance']
# Index(['name', 'dept', 'salary'], dtype='object')

# %%
data[['name','dept']]
# Out:
#       name      dept
# 101   john        IT
# 102   alex     sales
# 103  smith  finnance

# %%
# Locate Row
data.loc[[102,103]]
# Out:
#       name      dept  salary
# 102   alex     sales   56000
# 103  smith  finnance  778000

# %%
# dat_range()
# yyyymmdd

dates=pd.date_range('20230101',periods=10)
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(10,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2023-01-01  1.651048 -1.637120 -0.396718 -0.087454
# 2023-01-02 -0.541975 -1.460415 -1.221841  0.212811
# 2023-01-03 -1.452455  2.047504  0.127782  1.121347
# 2023-01-04 -0.132283 -1.146051 -0.572588  1.061919
# 2023-01-05  1.670857  0.938670 -1.281345  0.729541
# 2023-01-06  1.243300 -0.591313 -0.727469 -1.579938
# 2023-01-07 -0.161295 -0.224652  0.877722  1.167509
# 2023-01-08 -0.942896  0.625257 -0.045230 -0.524622
# 2023-01-09 -1.687338 -0.376640 -0.269511  1.330391
# 2023-01-10 -0.323761 -1.220721 -0.988197  0.388042

# %%
emp_info = {'Id':[101,102,103,104,105,106] , 'Name':['John','Smith','Nurul','Tom','Harry','Smith']
            , 'Salary':[1000,2000,3000,1200,2800,3200]
            ,'Dept':['Finance','Sales','HR','IT','Marketing','Sales']}
data = pd.DataFrame(emp_info)
data
# Out:
#     Id   Name  Salary       Dept
# 0  101   John    1000    Finance
# 1  102  Smith    2000      Sales
# 2  103  Nurul    3000         HR
# 3  104    Tom    1200         IT
# 4  105  Harry    2800  Marketing
# 5  106  Smith    3200      Sales

# %%
data[(data['Salary']>1500) & (data['Dept']=='Sales')]
# Out:
#     Id   Name  Salary   Dept
# 1  102  Smith    2000  Sales
# 5  106  Smith    3200  Sales
