# %% [markdown]
# <a href="https://colab.research.google.com/github/ScriptSherpa/python-and-ds/blob/main/iguru27(B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.anaconda.com/download/success

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
print(sns.__version__)
# Out:
# 0.13.2

# %%
# built in data sets of seborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dataset= sns.load_dataset('iris')
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Line Graph --> lineplot()
sns.set_style('darkgrid',{'grid.color':'k','grid.linestyle':':'})
sns.lineplot(x='sepal_length', y='sepal_width', data=dataset)
plt.title('Line Graph in Seaborn')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
pokemon =pd.read_csv("https://raw.githubusercontent.com/yash240990/Python/master/pokemon.csv")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Scatter plot
sns.scatterplot(x='Attack', y='Defense', hue='Generation',data=pokemon)
plt.title('Scatter Plot in Seaborn')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.show()

# %%
pokemon.Generation.value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
colors=['r','y','b','g','c','m']
sns.scatterplot(x='Attack', y='Defense', hue='Generation',palette=colors,data=pokemon)
plt.title('Scatter Plot in Seaborn')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.show()

# %%
#lmplot()
#used to generate a scatter plot using regression line
colors=['r','y','b','g','c','m']
sns.lmplot(x='Attack', y='Defense', hue='Generation',palette=pkmn_type_colors,data=pokemon)
plt.title('Scatter Plot in Seaborn')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.show()

# %%
#count plot
# generate bar graph

plt.figure(figsize=(10,5))
sns.countplot(x='Type 1',data=pokemon)
plt.title('Count Plot in Seaborn')
plt.xlabel('Generation')
plt.ylabel('Count')
plt.show()

# %%
pkmn_type_colors =[ '#0DEC25',  # Grass
                    '#EC1E09',  # Fire
                    '#0AE3D6',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#ECF709',  # Dragon
                    '#7A786C',  # Dark
                    '#D3D1C0',  # Steel
                    '#91E8EE',  # Flying
                   ]

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Type 1',palette=pkmn_type_colors,data=pokemon)
plt.title('Count Plot in Seaborn')
plt.xlabel('Generation')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Type 1',palette=pkmn_type_colors,data=pokemon)
plt.title('Count Plot in Seaborn')
plt.xticks(rotation=45)
plt.show()

# %%
# replot()
tips=sns.load_dataset('tips')
tips


sns.relplot(x='total_bill', y='tip',hue='smoker',col='sex', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip',hue='day',col='time', data=tips)
plt.show()
