# %% [markdown]
# <a href="https://colab.research.google.com/github/ScriptSherpa/python-and-ds/blob/main/malyasianproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# Load the HTML file
with open('/content/USER_ENGAGEMENT_SURVEY.html', 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file, 'html.parser')

# Example: Extract all tables
tables = soup.find_all('table')
for idx, table in enumerate(tables):
    print(f"Table {idx + 1}:\n{table}")

# Convert table data to DataFrame (if applicable)
import pandas as pd
rows = []
for row in tables[0].find_all('tr'):
    cells = row.find_all('td')
    rows.append([cell.text.strip() for cell in cells])
df = pd.DataFrame(rows)
print(df)
# Out:
# Table 1:
# <table border="1" class="dataframe">
# <thead>
# <tr style="text-align: right;">
# <th></th>
# <th>Timestamp</th>
# <th>By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.</th>
# <th>What is your age?</th>
# <th>What is your gender?</th>
# <th>What is your occupation?</th>
# <th>How often do you use the internet?</th>
# <th>Which device do you primarily use to access the internet?</th>
# <th>What is your main reason for using the internet?</th>
# <th>What types of Malaysian web platforms do you frequently visit?</th>
# <th>How often do you interact with online shopping on websites?</th>
# <th>How often do you interact with reading articles on websites?</th>
# <th>How often do you interact with watching videos on websites?</th>
# ...

# %%
from bs4 import BeautifulSoup
import pandas as pd

# Load the HTML file (assuming it's in the same directory)
with open('/content/USER_ENGAGEMENT_SURVEY.html', 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file, 'html.parser')

# Extract the first table
table = soup.find('table')  # Get the first table only

#

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                              0      1         2       3              4   \
# 0                          None   None      None    None           None
# 1  2024/12/24 11:33:49 AM GMT+8  Agree  Under 18  Female       Employed
# 2  2024/12/24 11:33:49 AM GMT+8  Agree   25 - 34  Female  Self-employed
# 3  2024/12/24 11:33:49 AM GMT+8  Agree   55 - 64  Female        Retired
# 4  2024/12/24 11:33:49 AM GMT+8  Agree   55 - 64  Female     Unemployed
#
#                       5           6             7                    8     9   \
# 0                   None        None          None                 None  None
# ...

# %%
# ... (your existing code to create the DataFrame 'df') ...

# 1. Inspect the data
print(df.head())
print(df.info())

# 2. Select and filter
responses = df['Response']  # Get the 'Response' column
filtered_df = df[df['Question'] == 'What is your favorite feature?']  # Filter rows

# 3. Manipulate columns
df = df.rename(columns={'Timestamp': 'Survey_Time'})  # Rename a column

# 4. (Optional) Handle missing values if any

# 5. Group and aggregate (if applicable)
# For example, if 'Response' is numerical, you could calculate the average response:
# average_response = df.groupby('Question')['Response'].mean()
# print(average_response)

# ... further analysis and visualization ...
# Out:
#                              0      1         2       3              4   \
# 0                          None   None      None    None           None
# 1  2024/12/24 11:33:49 AM GMT+8  Agree  Under 18  Female       Employed
# 2  2024/12/24 11:33:49 AM GMT+8  Agree   25 - 34  Female  Self-employed
# 3  2024/12/24 11:33:49 AM GMT+8  Agree   55 - 64  Female        Retired
# 4  2024/12/24 11:33:49 AM GMT+8  Agree   55 - 64  Female     Unemployed
#
#                       5           6             7                    8     9   \
# 0                   None        None          None                 None  None
# 1  Several times a month      Laptop     Education  Government services     4
# 2                 Rarely      Laptop          Work         News portals     3
# 3           Once a month  Smartphone  Social Media  Government services     4
# 4                 Rarely      Tablet  Social Media           E-commerce     3
#
# ...

# %%
from bs4 import BeautifulSoup
import pandas as pd

# ... (load the HTML as before) ...

# Extract headings (e.g., h1, h2, h3)
headings = soup.find_all(['h1', 'h2', 'h3'])  # Specify the heading tags you want

for heading in headings:
    print(f"Heading: {heading.text}")

# ... (your existing table extraction code) ...

# Now, 'df' contains your table data,
# and you've also printed the extracted headings separately.

# %%
from bs4 import BeautifulSoup
import pandas as pd

# ... (load the HTML as before) ...

# Extract headings (e.g., h1, h2, h3)
headings = soup.find_all(['h1', 'h2', 'h3'])  # Specify the heading tags you want

for heading in headings:
    print(f"Heading: {heading.text}")

# ... (your existing table extraction code) ...

# Now, 'df' contains your table data,
# and you've also printed the extracted headings separately.

# %%
from bs4 import BeautifulSoup
import pandas as pd

# ... (load the HTML as before) ...

# Extract headings (e.g., h1, h2, h3)
headings = soup.find_all(['h1', 'h2', 'h3'])  # Specify the heading tags you want

for heading in headings:
    print(f"Heading: {heading.text}")

# ... (your existing table extraction code) ...

# Now, 'df' contains your table data,
# and you've also printed the extracted headings separately.

# %%
import pandas as pd

file_path = '/content/UserEngagementSurvey.xlsx'
df = pd.read_excel(file_path)

# Optional: Print the first few rows to check
print(df.head())
# Out:
#                       Timestamp  \
# 0  2024/12/24 11:33:49 AM GMT+8
# 1  2024/12/24 11:33:49 AM GMT+8
# 2  2024/12/24 11:33:49 AM GMT+8
# 3  2024/12/24 11:33:49 AM GMT+8
# 4  2024/12/24 11:33:49 AM GMT+8
#
#   By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.   \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   What is your age? What is your gender? What is your occupation?  \
# 0          Under 18               Female                 Employed
# 1           25 - 34               Female            Self-employed
# ...

# %%
# ... (your code to load the Excel file) ...

# Get the column names (headings)
headings = df.columns.tolist()

# Print the headings
print(headings)

# %%
# ... (your code to load the Excel file) ...

# Get the column names (headings)
headings = df.columns.tolist()

# Print the headings
print(headings)
# Out:
# ['Timestamp', "By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate. ", 'What is your age?', 'What is your gender?', 'What is your occupation?', 'How often do you use the internet?', 'Which device do you primarily use to access the internet?', 'What is your main reason for using the internet?', 'What types of Malaysian web platforms do you frequently visit?', 'How often do you interact with online shopping on websites?', 'How often do you interact with reading articles on websites?', 'How often do you interact with watching videos on websites?', 'How often do you interact with participating in online discussions on websites?', 'How often do you interact with social media integration on websites?', "How satisfied are you with the overall user experience of Malaysian web platforms? (
# ...

# %%
import pandas as pd

# ... (your code to load the Excel file) ...

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Now, print the DataFrame to see the full table
print(df)
# Out:
#                         Timestamp  \
# 0    2024/12/24 11:33:49 AM GMT+8
# 1    2024/12/24 11:33:49 AM GMT+8
# 2    2024/12/24 11:33:49 AM GMT+8
# 3    2024/12/24 11:33:49 AM GMT+8
# 4    2024/12/24 11:33:49 AM GMT+8
# 5    2024/12/24 11:33:49 AM GMT+8
# 6    2024/12/24 11:33:49 AM GMT+8
# 7    2024/12/24 11:33:49 AM GMT+8
# 8    2024/12/24 11:33:49 AM GMT+8
# 9    2024/12/24 11:33:49 AM GMT+8
# 10   2024/12/24 11:33:49 AM GMT+8
# 11   2024/12/24 11:33:49 AM GMT+8
# 12   2024/12/24 11:33:49 AM GMT+8
# 13   2024/12/24 11:33:49 AM GMT+8
# 14   2024/12/24 11:33:49 AM GMT+8
# 15   2024/12/24 11:33:50 AM GMT+8
# 16   2024/12/24 11:33:50 AM GMT+8
# 17   2024/12/24 11:33:50 AM GMT+8
# 18   2024/12/24 11:33:50 AM GMT+8
# 19   2024/12/24 11:33:50 AM GMT+8
# 20   2024/12/24 11:33:50 AM GMT+8
# 21   2024/12/24 11:33:50 AM GMT+8
# 22   2024/12/24 11:33:50 AM GMT+8
# 23   2024/12/24 11:33:50 AM GMT+8
# 24   2024/12/24 11:33:50 AM GMT+8
# 25   2024/12/24 11:33:50 AM GMT+8
# ...

# %%
# ... (your code to load the Excel file) ...

# Get the headings in a list
headings = df.columns.tolist()

# Print the headings point-wise
for i, heading in enumerate(headings):
    print(f"{i + 1}. {heading}")
# Out:
# 1. Timestamp
# 2. By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.
# 3. What is your age?
# 4. What is your gender?
# 5. What is your occupation?
# 6. How often do you use the internet?
# 7. Which device do you primarily use to access the internet?
# 8. What is your main reason for using the internet?
# 9. What types of Malaysian web platforms do you frequently visit?
# 10. How often do you interact with online shopping on websites?
# 11. How often do you interact with reading articles on websites?
# 12. How often do you interact with watching videos on websites?
# 13. How often do you interact with participating in online discussions on websites?
# 14. How often do you interact with social media integration on websites?
# ...

# %%
# ... (your code to load the Excel file) ...

# Define the new headings
new_headings = [
    "Timestamp",
    "Consent Confirmation",
    "Age",
    "Gender",
    "Occupation",
    "Internet Usage Frequency",
    "Primary Access Device",
    "Main Internet Purpose",
    "Frequent Malaysian Platforms",
    "Online Shopping Frequency",
    "Article Reading Frequency",
    "Video Watching Frequency",
    "Online Discussion Frequency",
    "Social Media Integration Usage",
    "User Experience Satisfaction",
    "Recommendation Likelihood",
    "Accessibility for Disabilities",
    "Success Finding Information",
    "Improvement Suggestions",
    "Desired Additional Features"
]

# Assign the new headings to the DataFrame's columns
df.columns = new_headings

# Optional: Print the DataFrame to check the changes
print(df.head())
# Out:
#                       Timestamp Consent Confirmation           Age  Gender  \
# 0  2024/12/24 11:33:49 AM GMT+8                Agree      Under 18  Female
# 1  2024/12/24 11:33:49 AM GMT+8                Agree       25 - 34  Female
# 2  2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 3  2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 4  2024/12/24 11:33:49 AM GMT+8                Agree  65 and above    Male
#
#       Occupation Internet Usage Frequency Primary Access Device  \
# 0       Employed    Several times a month                Laptop
# 1  Self-employed                   Rarely                Laptop
# 2        Retired             Once a month            Smartphone
# 3     Unemployed                   Rarely                Tablet
# 4     Unemployed    Several times a month                Laptop
#
#   Main Internet Purpose Frequent Malaysian Platforms  \
# 0             Education          Government services
# ...

# %%
import pandas as pd

# ... (your code to load the Excel file) ...

# Define the new headings (as provided previously)
new_headings = [
    "Timestamp", "Consent Confirmation", "
# Out:
#   File "<ipython-input-14-32439a56380e>", line 7
#     "Timestamp", "Consent Confirmation", "
#                                          ^
# SyntaxError: unterminated string literal (detected at line 7)

# %%
import pandas as pd

# ... (your code to load the Excel file) ...

# Define the new headings (as provided previously)
new_headings = [
    "Timestamp", "Consent Confirmation", "Age", "Gender", "Occupation",
    "Internet Usage Frequency", "Primary Access Device", "Main Internet Purpose",
    "Frequent Malaysian Platforms", "Online Shopping Frequency", "Article Reading Frequency",
    "Video Watching Frequency", "Online Discussion Frequency", "Social Media Integration Usage",
    "User Experience Satisfaction", "Recommendation Likelihood", "Accessibility for Disabilities",
    "Success Finding Information", "Improvement Suggestions", "Desired Additional Features"
]

# Assign the new headings to the DataFrame's columns
df.columns = new_headings

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Now, print the DataFrame to see the full table
print(df)
# Out:
#                         Timestamp Consent Confirmation           Age  Gender  \
# 0    2024/12/24 11:33:49 AM GMT+8                Agree      Under 18  Female
# 1    2024/12/24 11:33:49 AM GMT+8                Agree       25 - 34  Female
# 2    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 3    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 4    2024/12/24 11:33:49 AM GMT+8                Agree  65 and above    Male
# 5    2024/12/24 11:33:49 AM GMT+8                Agree      Under 18  Female
# 6    2024/12/24 11:33:49 AM GMT+8                Agree       25 - 34  Female
# 7    2024/12/24 11:33:49 AM GMT+8                Agree  65 and above  Female
# 8    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 9    2024/12/24 11:33:49 AM GMT+8                Agree       45 - 54    Male
# 10   2024/12/24 11:33:49 AM GMT+8                Agree       45 - 54  Female
# ...

# %%
import pandas as pd

# ... (your code to load the Excel file) ...

# Define the new headings (as provided previously)
new_headings = [
    "Timestamp", "Consent Confirmation", "Age", "Gender", "Occupation",
    "Internet Usage Frequency", "Primary Access Device", "Main Internet Purpose",
    "Frequent Malaysian Platforms", "Online Shopping Frequency", "Article Reading Frequency",
    "Video Watching Frequency", "Online Discussion Frequency", "Social Media Integration Usage",
    "User Experience Satisfaction", "Recommendation Likelihood", "Accessibility for Disabilities",
    "Success Finding Information", "Improvement Suggestions", "Desired Additional Features"
]

# Assign the new headings to the DataFrame's columns
df.columns = new_headings

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Now, print the DataFrame to see the full table
print(df)
# Out:
#                         Timestamp Consent Confirmation           Age  Gender  \
# 0    2024/12/24 11:33:49 AM GMT+8                Agree      Under 18  Female
# 1    2024/12/24 11:33:49 AM GMT+8                Agree       25 - 34  Female
# 2    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 3    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 4    2024/12/24 11:33:49 AM GMT+8                Agree  65 and above    Male
# 5    2024/12/24 11:33:49 AM GMT+8                Agree      Under 18  Female
# 6    2024/12/24 11:33:49 AM GMT+8                Agree       25 - 34  Female
# 7    2024/12/24 11:33:49 AM GMT+8                Agree  65 and above  Female
# 8    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 9    2024/12/24 11:33:49 AM GMT+8                Agree       45 - 54    Male
# 10   2024/12/24 11:33:49 AM GMT+8                Agree       45 - 54  Female
# ...

# %%
print(df)
# Out:
#                         Timestamp Consent Confirmation           Age  Gender  \
# 0    2024/12/24 11:33:49 AM GMT+8                Agree      Under 18  Female
# 1    2024/12/24 11:33:49 AM GMT+8                Agree       25 - 34  Female
# 2    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 3    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 4    2024/12/24 11:33:49 AM GMT+8                Agree  65 and above    Male
# 5    2024/12/24 11:33:49 AM GMT+8                Agree      Under 18  Female
# 6    2024/12/24 11:33:49 AM GMT+8                Agree       25 - 34  Female
# 7    2024/12/24 11:33:49 AM GMT+8                Agree  65 and above  Female
# 8    2024/12/24 11:33:49 AM GMT+8                Agree       55 - 64  Female
# 9    2024/12/24 11:33:49 AM GMT+8                Agree       45 - 54    Male
# 10   2024/12/24 11:33:49 AM GMT+8                Agree       45 - 54  Female
# ...

# %%
import pandas as pd

# ... (your code to load the Excel file and update headings) ...

# Save the DataFrame to a new Excel file
df.to_excel('updated_UserEngagementSurvey.xlsx', index=False)

print("Excel file 'updated_UserEngagementSurvey.xlsx' has been created.")
# Out:
# Excel file 'updated_UserEngagementSurvey.xlsx' has been created.
